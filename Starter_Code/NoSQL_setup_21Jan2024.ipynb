0'), 'BusinessType': 'Restaurant/Cafe/Canteen', 'BusinessTypeID': {'1': 'BusinessTypeID'}}
# {'_id': ObjectId('65adf425621145dd96f0d0ba'), 'BusinessType': 'Restaurant/Cafe/Canteen', 'BusinessTypeID': ''}
# {'_id': ObjectId('65adfe3610d68685e1fe8b9f'), 'BusinessType': 'Restaurant/Cafe/Canteen', 'BusinessTypeID': ''}

# %% [markdown]
# 3. Update the new restaurant with the `BusinessTypeID` you found.

# %%
# Update the new restaurant with the correct BusinessTypeID
establishments.update_one({'BusinessName':'Penang Flavours'}, { '$set': { "BusinessTypeID" : '1'}})

#establishments.update_many(new_restaurant, [ {'$set':{ "BusinessTypeID" : {'1': "BusinessTypeID"}}} ])
# Out:
# UpdateResult({'n': 1, 'nModified': 0, 'ok': 1.0, 'updatedExisting': True}, acknowledged=True)

# %%
# Confirm that the new restaurant was updated
db.establishments.find_one(new_restaurant)
# Out:
# {'_id': ObjectId('65adfe3610d68685e1fe8b9f'),
#  'BusinessName': 'Penang Flavours',
#  'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': '',
#  'AddressLine1': 'Penang Flavours',
#  'AddressLine2': '146A Plumstead Rd',
#  'AddressLine3': 'London',
#  'AddressLine4': '',
#  'PostCode': 'SE18 7DY',
#  'Phone': '',
#  'LocalAuthorityCode': '511',
#  'LocalAuthorityName': 'Greenwich',
#  'LocalAuthorityWebSite': 'http://www.royalgreenwich.gov.uk',
#  'LocalAuthorityEmailAddress': 'health@royalgreenwich.gov.uk',
#  'scores': {'Hygiene': '', 'Structural': '', 'ConfidenceInManagement': ''},
#  'SchemeType': 'FHRS',
#  'geocode': {'longitude': '0.08384000', 'latitude': '51.49014200'},
#  'RightToReply': '',
#  'Distance': 4623.972328074718,
#  'NewRatingPending': True}

# %% [markdown]
# 4. The magazine is not interested in any establishments in Dover, so check how many documents contain the Dover Local Authority. Then, remove any establishments within the Dover Local Authority from the database, and check the number of documents to ensure they were deleted.

# %%
# Find how many documents have LocalAuthorityName as "Dover"
query={'LocalAuthorityName': {'$eq':'Dover'}}

#pprint(list(establishments.find(query)))

len(list(establishments.find(query)))
# Out:
# 0

# %%
# Delete all documents where LocalAuthorityName is "Dover"
query = {'LocalAuthorityName': {'$eq':'Dover'}}
establishments.delete_many(query)

results = establishments.find(query)
for result in results:
    print(result)

# %%
# Check if any remaining documents include Dover
len(list(establishments.find(query)))
# Out:
# 0

# %%
# Check that other documents remain with 'find_one'
db.establishments.find_one()
# Out:
# {'_id': ObjectId('65adc89b7334aa12347553ae'),
#  'FHRSID': 1043695,
#  'ChangesByServerID': 0,
#  'LocalAuthorityBusinessID': 'PI/000073616',
#  'BusinessName': 'The Pavilion',
#  'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  'AddressLine1': 'East Cliff Pavilion',
#  'AddressLine2': 'Wear Bay Road',
#  'AddressLine3': 'Folkestone',
#  'AddressLine4': 'Kent',
#  'PostCode': 'CT19 6BL',
#  'Phone': '',
#  'RatingValue': '5',
#  'RatingKey': 'fhrs_5_en-gb',
#  'RatingDate': '2018-04-04T00:00:00',
#  'LocalAuthorityCode': '188',
#  'LocalAuthorityName': 'Folkestone and Hythe',
#  'LocalAuthorityWebSite': 'http://www.folkestone-hythe.gov.uk',
#  'LocalAuthorityEmailAddress': 'foodteam@folkestone-hythe.gov.uk',
#  'scores': {'Hygiene': 5, 'Structural': 5, 'ConfidenceInManagement': 5},
#  'SchemeType': 'FHRS',
#  'geocode': {'longitude': '1.195625', 'latitude': '51.083812'},
#  'RightToReply': '',
#  'Distance': 4591.765489457773,
#  'NewRatingPending': False,
#  'meta': {'dataSource': None,
#   'extractDate': '0001-01-01T00:00:00',
#   'itemCount': 0,
#   'returncode': None,
#   'totalCount': 0,
#   'totalPages': 0,
#   'pageSize': 0,
#   'pageNumber': 0},
#  'links': [{'rel': 'self',
#    'href': 'https://api.ratings.food.gov.uk/establishments/1043695'}]}

# %% [markdown]
# 5. Some of the number values are stored as strings, when they should be stored as numbers.

# %% [markdown]
# Use `update_many` to convert `latitude` and `longitude` to decimal numbers.

# %%
# Change the data type from String to Decimal for longitude and latitude
establishments.update_many({}, [ {'$set':{ "geocode.longitude" : {'$toDouble': "geocode.longitude"}}} ])

establishments.update_many({}, [ {'$set':{ "geocode.latitude" : {'$toDouble': "geocode.latitude"}}} ])

query = {}
fields = {'geocode.longitude': 1, 'geocode.latitude': 1}

# Capture the results to a variable
results = establishments.find(query, fields)

# Pretty print the results
for result in results:
    pprint(result)
# Out:
# ---------------------------------------------------------------------------
# WriteError                                Traceback (most recent call last)
# Cell In[20], line 2
#       1 # Change the data type from String to Decimal for longitude and latitude
# ----> 2 establishments.update_many({}, [ {'$set':{ "geocode.longitude" : {'$toDouble': "geocode.longitude"}}} ])
#       4 establishments.update_many({}, [ {'$set':{ "geocode.latitude" : {'$toDouble': "geocode.latitude"}}} ])
#       6 query = {}
#
# File ~\anaconda3\envs\dev\lib\site-packages\pymongo\collection.py:1187, in Collection.update_many(self, filter, update, upsert, array_filters, bypass_document_validation, collation, hint, session, let, comment)
#    1183 common.validate_list_or_none("array_filters", array_filters)
#    1185 write_concern = self._write_concern_for(session)
#    1186 return UpdateResult(
# -> 1187     self._update_retryable(
#    1188         filter,
#    1189         update,
#    1190         upsert,
#    1191         multi=True,
#    1192         write_concern=write_concern,
#    1193         bypass_doc_val=bypass_document_validation,
#    1194         collation=collation,
#    1195         array_filters=array_filters,
#    1196         hint=hint,
#    1197         session=session,
#    1198         let=let,
#    1199         comment=comment,
#    1200     ),
#    1201     write_concern.acknowledged,
#    1202 )
#
# File ~\anaconda3\envs\dev\lib\site-packages\pymongo\collection.py:881, in Collection._update_retryable(self, criteria, document, upsert, multi, write_concern, op_id, ordered, bypass_doc_val, collation, array_filters, hint, session, let, comment)
#     859 def _update(
#     860     session: Optional[ClientSession], conn: Connection, retryable_write: bool
#     861 ) -> Optional[Mapping[str, Any]]:
#     862     return self._update(
#     863         conn,
#     864         criteria,
#    (...)
#     878         comment=comment,
#     879     )
# --> 881 return self.__database.client._retryable_write(
#     882     (write_concern or self.write_concern).acknowledged and not multi, _update, session
#     883 )
#
# File ~\anaconda3\envs\dev\lib\site-packages\pymongo\mongo_client.py:1523, in MongoClient._retryable_write(self, retryable, func, session, bulk)
#    1509 """Execute an operation with consecutive retries if possible
#    1510
#    1511 Returns func()'s return value on success. On error retries the same
#    (...)
#    1520   - `bulk`: bulk abstraction to execute operations in bulk, defaults to None
#    1521 """
#    1522 with self._tmp_session(session) as s:
# -> 1523     return self._retry_with_session(retryable, func, s, bulk)
#
# File ~\anaconda3\envs\dev\lib\site-packages\pymongo\mongo_client.py:1421, in MongoClient._retry_with_session(self, retryable, func, session, bulk)
#    1416 # Ensure that the options supports retry_writes and there is a valid session not in
#    1417 # transaction, otherwise, we will not support retry behavior for this txn.
#    1418 retryable = bool(
#    1419     retryable and self.options.retry_writes and session and not session.in_transaction
#    1420 )
# -> 1421 return self._retry_internal(
#    1422     func=func,
#    1423     session=session,
#    1424     bulk=bulk,
#    1425     retryable=retryable,
#    1426 )
#
# File ~\anaconda3\envs\dev\lib\site-packages\pymongo\_csot.py:107, in apply.<locals>.csot_wrapper(self, *args, **kwargs)
#     105         with _TimeoutContext(timeout):
#     106             return func(self, *args, **kwargs)
# --> 107 return func(self, *args, **kwargs)
#
# File ~\anaconda3\envs\dev\lib\site-packages\pymongo\mongo_client.py:1462, in MongoClient._retry_internal(self, func, session, bulk, is_read, address, read_pref, retryable)
#    1428 @_csot.apply
#    1429 def _retry_internal(
#    1430     self,
#    (...)
#    1437     retryable: bool = False,
#    1438 ) -> T:
#    1439     """Internal retryable helper for all client transactions.
#    1440
#    1441     :Parameters:
#    (...)
#    1451       Output of the calling func()
#    1452     """
#    1453     return _ClientConnectionRetryable(
#    1454         mongo_client=self,
#    1455         func=func,
#    1456         bulk=bulk,
#    1457         is_read=is_read,
#    1458         session=session,
#    1459         read_pref=read_pref,
#    1460         address=address,
#    1461         retryable=retryable,
# -> 1462     ).run()
#
# File ~\anaconda3\envs\dev\lib\site-packages\pymongo\mongo_client.py:2315, in _ClientConnectionRetryable.run(self)
#    2313 self._check_last_error(check_csot=True)
#    2314 try:
# -> 2315     return self._read() if self._is_read else self._write()
#    2316 except ServerSelectionTimeoutError:
#    2317     # The application may think the write was never attempted
#    2318     # if we raise ServerSelectionTimeoutError on the retry
#    2319     # attempt. Raise the original exception instead.
#    2320     self._check_last_error()
#
# File ~\anaconda3\envs\dev\lib\site-packages\pymongo\mongo_client.py:2423, in _ClientConnectionRetryable._write(self)
#    2421             self._check_last_error()
#    2422             self._retryable = False
# -> 2423         return self._func(self._session, conn, self._retryable)  # type: ignore
#    2424 except PyMongoError as exc:
#    2425     if not self._retryable:
#
# File ~\anaconda3\envs\dev\lib\site-packages\pymongo\collection.py:862, in Collection._update_retryable.<locals>._update(session, conn, retryable_write)
#     859 def _update(
#     860     session: Optional[ClientSession], conn: Connection, retryable_write: bool
#     861 ) -> Optional[Mapping[str, Any]]:
# --> 862     return self._update(
#     863         conn,
#     864         criteria,
#     865         document,
#     866         upsert=upsert,
#     867         multi=multi,
#     868         write_concern=write_concern,
#     869         op_id=op_id,
#     870         ordered=ordered,
#     871         bypass_doc_val=bypass_doc_val,
#     872         collation=collation,
#     873         array_filters=array_filters,
#     874         hint=hint,
#     875         session=session,
#     876         retryable_write=retryable_write,
#     877         let=let,
#     878         comment=comment,
#     879     )
#
# File ~\anaconda3\envs\dev\lib\site-packages\pymongo\collection.py:825, in Collection._update(self, conn, criteria, document, upsert, multi, write_concern, op_id, ordered, bypass_doc_val, collation, array_filters, hint, session, retryable_write, let, comment)
#     814 # The command result has to be published for APM unmodified
#     815 # so we make a shallow copy here before adding updatedExisting.
#     816 result = conn.command(
#     817     self.__database.name,
#     818     command,
#    (...)
#     823     retryable_write=retryable_write,
#     824 ).copy()
# --> 825 _check_write_command_response(result)
#     826 # Add the updatedExisting field for compatibility.
#     827 if result.get("n") and "upserted" not in result:
#
# File ~\anaconda3\envs\dev\lib\site-packages\pymongo\helpers.py:266, in _check_write_command_response(result)
#     264 write_errors = result.get("writeErrors")
#     265 if write_errors:
# --> 266     _raise_last_write_error(write_errors)
#     268 wce = _get_wce_doc(result)
#     269 if wce:
#
# File ~\anaconda3\envs\dev\lib\site-packages\pymongo\helpers.py:239, in _raise_last_write_error(write_errors)
#     237 if error.get("code") == 11000:
#     238     raise DuplicateKeyError(error.get("errmsg"), 11000, error)
# --> 239 raise WriteError(error.get("errmsg"), error.get("code"), error)
#
# WriteError: Failed to parse number 'geocode.longitude' in $convert with no onError value: Did not consume any digits, full error: {'index': 0, 'code': 241, 'errmsg': "Failed to parse number 'geocode.longitude' in $convert with no onError value: Did not consume any digits"}

# %% [markdown]
# Use `update_many` to convert `RatingValue` to integer numbers.

# %%
# Set non 1-5 Rating Values to Null
non_ratings = ["AwaitingInspection", "Awaiting Inspection", "AwaitingPublication", "Pass", "Exempt"]
establishments.update_many({"RatingValue": {"$in": non_ratings}}, [ {'$set':{ "RatingValue" : None}} ])

# %%
# Change the data type from String to Integer for RatingValue

# %%
# Check that the coordinates and rating value are now numbers
